# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # Proyecto: Riesgo en el Banco Giturra
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Gabriel Iturra, Ignacio Meza De La Jara
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---
#
# ## Reglas
#
# - Fecha de entrega: 19/12/2023
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ---

# %% [markdown]
# # Presentación del Problema

# %% [markdown]
# ![](https://www.diarioeldia.cl/u/fotografias/fotosnoticias/2019/11/8/67218.jpg)

# %% [markdown]
# **Giturra**, un banquero astuto y ambicioso, estableció su propio banco con el objetivo de obtener enormes ganancias. Sin embargo, su reputación se vio empañada debido a las tasas de interés usureras que imponía a sus clientes. A medida que su banco crecía, Giturra enfrentaba una creciente cantidad de préstamos impagados, lo que amenazaba su negocio y su prestigio.
#
# Para abordar este desafío, Giturra reconoció la necesidad de reducir los riesgos de préstamo y mejorar la calidad de los préstamos otorgados. Decidió aprovechar la ciencia de datos y el análisis de riesgo crediticio. Contrató a un equipo de expertos para desarrollar un modelo predictivo de riesgo crediticio.
#
# Cabe señalar que lo modelos solicitados por el banquero deben ser interpretables. Ya que estos le permitira al equipo comprender y explicar cómo se toman las decisiones crediticias. Utilizando visualizaciones claras y explicaciones detalladas, pudieron identificar las características más relevantes, le permitirá analizar la distribución de la importancia de las variables y evaluar si los modelos son coherentes con el negocio.
#
# Para esto Giturra les solicita crear un modelo de riesgo disponibilizandoles una amplia gama de variables de sus usuarios: como historiales de crédito, ingresos y otros factores financieros relevantes, para evaluar la probabilidad de incumplimiento de pago de los clientes. Con esta información, Giturra podra tomar decisiones más informadas en cuanto a los préstamos, ofreciendo condiciones más favorables a aquellos con menor riesgo de impago.

# %% [markdown]
# ## Instalación de Librerías y Carga de Datos.

# %% [markdown]
# Para el desarrollo de su proyecto, utilice el conjunto de datos `dataset.pq` para entrenar un modelo de su elección. Se le recomienda levantar un ambiente de `conda` para instalar las librerías y así evitar cualquier problema con las versiones.

# %% [markdown]
# ---
#
# ## Secciones Requeridas en el Informe
#
# La siguiente lista detalla las secciones que debe contener su notebook para resolver el proyecto.
# Es importante que al momento de desarrollar cada una de las secciones, estas sean escritas en un formato tipo **informe**, donde describan detalladamente cada uno de los puntos realizados.
#
# ### 1. Introducción [0.5 puntos]
#
# _Esta sección es literalmente una muy breve introducción con todo lo necesario para entender que hicieron en su proyecto._
#
# - Describir brevemente el problema planteado (¿Qué se intenta predecir?)
# - Describir brevemente los datos de entrada que les provee el problema.
# - Describir las métricas que utilizarán para evaluar los modelos generados. Eligan **una métrica** adecuada para el desarrollo del proyecto **según la tarea que deben resolver y la institución a la cuál será su contraparte** y luego justifiquen su elección. Considerando que los datos presentan desbalanceo y que el uso de la métrica 'accuracy' sería incorrecto, enfoquen su elección en una de las métricas precision, recall o f1-score y en la clase que será evaluada.
# - [Escribir al final] Describir brevemente el modelo que usaron para resolver el problema (incluyendo las transformaciones intermedias de datos).
# - [Escribir al final] Indicar si lograron resolver el problema a través de su modelo. Indiquen además si creen que los resultados de su mejor modelo son aceptables y como les fue con respecto al resto de los equipos.
#
# ### 2. Carga de datos Análisis Exploratorio de Datos [Sin puntaje]
#
# _La idea de esta sección es que cargen y exploren el dataset para así obtener una idea de como son los datos y como se relacionan con el problema._
#
# Cargue los datos y realice un análisis exploratorio de datos para investigar patrones, tendencias y relaciones en un conjunto de datos. Se adjuntan diversos scripts para abodar rápidamente este punto. La descripción de las columnas las pueden encontrar en el siguiente [enlace](https://www.kaggle.com/datasets/parisrohan/credit-score-classification).
#
# **NO deben escribir nada**, solo ejecutar el código y encontrar los patrones con los cuales se basaran para generar el modelo.
#
# ### 3. Preparación de Datos [0.5 puntos]
#
# _Esta sección consiste en generar los distintos pasos para preparar sus datos con el fin de luego poder crear su modelo._
#
# #### 3.1 Preprocesamiento con `ColumnTransformer`
#
# - Convierta las columnas mal leidas a sus tipos correspondientes (float, str, etc...)
# - Genere un `ColumnTransformer` que:
#   - Preprocese datos categóricos y ordinales.
#   - Escale/estandarice datos numéricos.
#   - Uitlice `.set_output(transform="pandas")` sobre su `ColumnTransformer` para setear el formato de salida a de las transformaciones a pandas.
#
# - Luego, pruebe las transformaciones utilizando `fit_transform`.
#
# - Posteriormente, ejecute un Holdout que le permita más adelante evaluar los modelos.
#
# #### 3.2 Holdout
#
# Ejecute `train_test_split` para generar un conjunto de entrenamiento, validacióny de prueba.
#
# #### 3.3 Datos nulos.
#
# Como habrá visto, existe la posibilidad de que algunos datos sean nulos. En esta sección se le solicita justificar, previo a comenzar el modelado, decidir si conservar e imputar los datos nulos o eliminar las filas.
#
# Note que la decisión que tomen aquí puede afectar fuertemente el rendimiento de los modelos.
# Y como siempre, más adelante tienen el espacio para experimentar con ambas opciones.
#
# #### 3.4 Feature Engineering [Bonus - 0.5 puntos]
#
# En esta sección, se espera que apliquen su conocimiento y creatividad para identificar y construir características que brinden una mejor orientación a su modelo para identificar los casos deseados. Para motivar la construcción de nuevas características, se recomienda explorar las siguientes posibilidades:
#
# - Generar ratios que relacionen variables categóricas con numéricas. Estos ratios permiten capturar relaciones proporcionales o comparativas entre diferentes categorías y valores numéricos.
# - Combinación de rankings entre variables numéricas y categóricas.
# - Discretización de variables numéricas a categóricas.
# - Etc...
#
# **Importantes**: Al explorar estas posibilidades no se limiten solo a estas propuestas, pueden aplicar otras técnicas de feature engineering pertinentes para mejorar la capacidad de su modelo para comprender y aprovechar los patrones presentes en los datos.
#
# ### 4. Baseline [1.5 puntos]
#
# _En esta sección deben crear los modelos más básicos posibles que resuelvan el problema dado. La idea de estos modelos son usarlos como comparación para que en el siguiente paso lo puedan mejorar._
#
# Implemente, entrene y evalúe varias `Pipeline` enfocadas en resolver el problema de clasificación en donde la diferencia entre estas sea el modelo utilizado.
#
#
# Para esto, cada Pipeline debe:
#
# - Tener el `ColumnTransformer` implementado en la sección anterior como primer paso.
# - Implementar un imputador en caso de haber decidido conservar los datos nulos.
# - Implementar un clasificador en la salida (ver siguiente lista).
#
# Y además,
# - Ser evaluado de forma general imprimiendo un `classification_report`.
# - Calcular y guardar la métrica seleccionada en el punto 1.2 en un arreglo de métricas (guardar nombre y valor de la métrica).
#
# Lo anterior debe ser implementado utilizando los siguientes modelos:
#
# - `Dummy` con estrategia estratificada.
# - `LogisticRegression`.
# - `KNeighborsClassifier`.
# - `DecisionTreeClassifier`
# - `SVC`
# - `RandomForestClassifier`
# - `LightGBMClassifier` (del paquete `lightgbm`)
# - `XGBClassifier` (del paquete `xgboost`).
#
#
# Luego, transformando el diccionario de las métricas a un pandas `DataFrame`, ordene según los valores de su métrica de mayor a menor y responda.
# - ¿Hay algún clasificador entrenado mejor que el azar (`Dummy`)?
# - ¿Cuál es el mejor clasificador entrenado?
# - ¿Por qué el mejor clasificador es mejor que los otros?
# - Respecto al tiempo de entrenamiento, con cual cree que sería mejor experimentar (piense en el tiempo que le tomaría pasar el modelo por una grilla de optimización de hiperparámetros).
#
# **Nota**: Puede utilizar un for más una lista con las clases de los modelos mencionados para simplificar el proceso anterior.
#
#
# ### 5. Optimización del Modelo [1.5 puntos]
#
# _En esta sección deben mejorar del modelo de clasificación al variar los algoritmos/hiperparámetros que están ocupando._
#
# - Instanciar dos nuevas `Pipeline`, similares a la anterior, pero ahora enfocada en buscar el mejor modelo. Para esto, la pipelines debe utilizar el primer y segundo mejor modelo encontrado en el paso anterior.
# - Usar **`Optuna`** para tunear hiperparámetros
# - **Importante**: Recuerden setear la búsqueda para optimizar la métrica seleccionada en los puntos anteriores.
#
# Algunas ideas para mejorar el rendimiento de sus modelos:
#
# - Agregar técnicas de seleccion de atributos/características. El parámetro de cuántas características se seleccionan debe ser parametrizable y configurado por el optimizador de hiperparámetros.
# - Variar el imputador de datos en caso de usarlo.
#
# #### Bonus
#
# 1. **Visualización con Optuna** [0.2 extras]: Explore la documentación de visualización de Optuna en el siguiente [link](https://optuna.readthedocs.io/en/stable/reference/visualization/index.html) y realice un análisis sobre el proceso de optimización de hiperparámetros realizado.
# 2. **Imabalanced learn** [0.3 extras]: Al ser el problema desbalanceado, pueden probar técnicas para balancear automáticamente el dataset previo a ejecutar el modelo. Para esto, puede probar con los mecanismos implementados en la librería [Imbalanced learn](https://imbalanced-learn.org/).
# 3. **Probar pycaret (AutoML)** [0.3 extras].
#
# Algunas notas interesantes sobre este proceso:
#
# - No se les pide rendimientos cercanos al 100% de la métrica para concretar exitosamente el proyecto. Por otra parte, celebren cada progreso que obtengan.
# - **Hacer grillas computables**: Si la grilla se va a demorar 1/3 la edad del universo en explorarse completamente, entonces achíquenla a algo que sepan que va a terminar.
# - Aprovechen el procesamiento paralelo (con `njobs`) para acelerar la búsqueda. Sin embargo, si tienen problemas con la memoria RAM, reduzca la cantidad de jobs a algo que su computador/interprete web pueda procesar.
#
# **Al final de este proceso, seleccione el mejor modelo encontrado, prediga el conjunto de prueba y reporte sus resultados.**

# %% [markdown]
# ### 6. Interpretabilidad [1.0 puntos]
#
# _En esta sección, se espera que los estudiantes demuestren su capacidad para explicar cómo sus modelos toman decisiones utilizando los datos. Dentro del análisis de interpretabilidad propuesto para el modelo, deberán ser capaces de:_
#
# - Proponer un método para analizar la interpretabilidad del modelo. Es crucial que puedan justificar por qué el método propuesto es el más adecuado y explicar los alcances que podría tener en su aplicación.
# - Identificar las características más relevantes del modelo. ¿La distribución de importancia es coherente y equitativa entre todas las variables?
# - Analizar 10 observaciones aleatorias utilizando un método específico para verificar la coherencia de las interacciones entre las características.
# - Explorar cómo se relacionan las variables utilizando algún descriptivo de interpretabilidad.
# - ¿Existen variables irrelevantes en el problema modelado?, ¿Cuales son?.
#
# Es fundamental que los estudiantes sean capaces de determinar si su modelo toma decisiones coherentes y evaluar el impacto que podría tener la aplicación de un modelo con esas variables en una población. ¿Es posible que el modelo sea perjudicial o que las estimaciones se basen en decisiones sesgadas?
#
# En resumen, esta sección busca que los estudiantes apliquen un enfoque crítico para evaluar la interpretabilidad de su modelo, identificar posibles sesgos y analizar las implicaciones de sus decisiones en la población objetivo.
#
# ### 7. Concluir [1.0 puntos]
#
# _Aquí deben escribir una breve conclusión del trabajo que hicieron en donde incluyan (pero no se limiten) a responder las siguientes preguntas:_
#
# - ¿Pudieron resolver exitosamente el problema?
# - ¿Son aceptables los resultados obtenidos?
# - ¿En que medida el EDA ayudó a comprender los datos en miras de generar un modelo predictivo?
#
# Respecto a la clasificación:
#
# - ¿Como fue el rendimiento del baseline para la clasificación?
# - ¿Pudieron optimizar el baseline para la clasificación?
# - ¿Que tanto mejoro el baseline de la clasificación con respecto a sus optimizaciones?
#
# Finalmente:
#
# - ¿Estuvieron conformes con sus resultados?
# - ¿Creen que hayan mejores formas de modelar el problema?
# - ¿En general, qué aprendieron del proyecto? ¿Qué no aprendieron y les gustaría haber aprendido?
#
# **OJO** si usted decide responder parte de estas preguntas, debe redactarlas en un formato de informe y no responderlas directamente.
#
# ### Otras Instrucciones
#
# Recordar el uso de buenas prácticas de MLOPS como replicabilidad (fijar semillas aleatorias) o el uso del registro de experimentos (con MLFlow). Si bien son opcionales, es altamente recomendado su uso.
#
# ### 8. Bonus: Implementación de Kedro y FastAPI [1.5 puntos]
#
# **OPCIONAL**
#
# En esta sección se les solicita utilizar las últimas tecnologías vistas en el curso para la productivización del proyecto de ciencia de datos, centrándose en la organización y gestión de los flujos de trabajo a través de componentes y pipelines, más el servicio del modelo a través del desarrollo de una API.
#
# Para esto:
#
# 1. Genere un proyecto de `Kedro` en donde separe por responsabilidades los nodos/componentes de su proyecto de ciencia de datos en módulos separados. [1.0 puntos]
# 2. Genere un servidor basado en `FastAPI` el cuál a través de un método post, reciba un batch de datos y genere predicciones para cada uno de ellos. [0.5 puntos]
#
# Las implementaciones son libres. Es decir, usted decide qué componentes implementar, como usar el catálogo de datos y la parametrización del flujo. Sin embargo, evaluaremos buen uso de los framework, modularización y separación de responsabilidades.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=87110296-876e-426f-b91d-aaf681223468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
# import dummmycls

# %%
# para instalar lightbgm necesaria para el modelo LightGBMClassifier
# !pip install lightgbm

# %%
# imports
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('pdf') # Para solucionar el error de guardar las img en pdf, Esto genera que no funcione el plt.show()
import seaborn as sns
import scipy.stats as ss
import numpy as np
import os 
import datetime
import pandas as pd
import re
import shutil
import time as tm
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans, SpectralClustering, AgglomerativeClustering, Birch, AffinityPropagation
from sklearn.dummy import DummyClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import IsolationForest
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from sklearn.metrics import classification_report, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from optuna.samplers import TPESampler
import optuna

# %%
# leemos el archivo .pq
dataset = pd.read_parquet('dataset.pq')

# %%
dataset
# Out:
#       customer_id   age     occupation  annual_income  monthly_inhand_salary  \
# 0       CUS_0xd40  23.0      Scientist       19114.12            1824.843333
# 1      CUS_0x21b1  28.0        Teacher       34847.84            3037.986667
# 2      CUS_0x2dbc  34.0       Engineer      143162.64           12187.220000
# 3      CUS_0xb891  55.0   Entrepreneur       30689.89            2612.490833
# 4      CUS_0x1cdb  21.0      Developer       35547.71            2853.309167
# ...           ...   ...            ...            ...                    ...
# 12495  CUS_0x372c  19.0         Lawyer       42903.79            3468.315833
# 12496   CUS_0xf16  45.0  Media_Manager       16680.35                    NaN
# 12497  CUS_0xaf61  50.0         Writer       37188.10            3097.008333
# 12498  CUS_0x8600  29.0      Architect       20002.88            1929.906667
# 12499  CUS_0x942c  25.0       Mechanic       39628.99            3359.415833
#
#        num_bank_accounts  num_credit_card  interest_rate  num_of_loan  \
# 0                      3                4              3          4.0
# 1                      2                4              6          1.0
# 2                      1                5              8          3.0
# 3                      2                5              4       -100.0
# 4                      7                5              5       -100.0
# ...                  ...              ...            ...          ...
# 12495                  0                4              6          1.0
# 12496                  1                1              5          4.0
# 12497                  1                4              5          3.0
# 12498                 10                8             29          5.0
# 12499                  4                6              7          2.0
#
#        delay_from_due_date  ...  num_credit_inquiries  outstanding_debt  \
# 0                        3  ...                   4.0            809.98
# 1                        3  ...                   2.0            605.03
# 2                        8  ...                   3.0           1303.01
# 3                        4  ...                   4.0            632.46
# 4                        1  ...                   4.0            943.86
# ...                    ...  ...                   ...               ...
# 12495                    9  ...                   1.0           1079.48
# 12496                    1  ...                   8.0            897.16
# 12497                    7  ...                   3.0            620.64
# 12498                   33  ...                   9.0           3571.70
# 12499                   18  ...                   3.0            502.38
#
#        credit_utilization_ratio  credit_history_age  payment_of_min_amount  \
# 0                     23.933795                 NaN                     No
# 1                     32.933856                27.0                     No
# 2                     38.374753                18.0                     No
# 3                     27.332515                17.0                     No
# 4                     25.862922                31.0                    Yes
# ...                         ...                 ...                    ...
# 12495                 35.716618                28.0                     No
# 12496                 41.212367                 NaN                     No
# 12497                 39.300980                30.0                     No
# 12498                 37.140784                 6.0                    Yes
# 12499                 34.192463                31.0                     No
#
#        total_emi_per_month amount_invested_monthly  \
# 0                49.574949               24.785217
# 1                18.816215              218.904344
# 2               246.992319            10000.000000
# 3                16.415452              125.617251
# 4                 0.000000              181.330901
# ...                    ...                     ...
# 12495            34.975457              115.184984
# 12496            41.113561               70.805550
# 12497            84.205949               42.935566
# 12498            60.964772               34.662906
# 12499            35.104023              167.163865
#
#                       payment_behaviour  monthly_balance credit_score
# 0      High_spent_Medium_value_payments       358.124168            0
# 1        Low_spent_Small_value_payments       356.078109            0
# 2       High_spent_Small_value_payments       895.494583            0
# 3       High_spent_Small_value_payments       379.216381            0
# 4       High_spent_Small_value_payments       364.000016            0
# ...                                 ...              ...          ...
# 12495  High_spent_Medium_value_payments              NaN            0
# 12496    Low_spent_Large_value_payments              NaN            0
# 12497  High_spent_Medium_value_payments              NaN            0
# 12498   High_spent_Large_value_payments              NaN            0
# 12499                            !@9#%8              NaN            1
#
# [12500 rows x 22 columns]

# %% [markdown]
# ## Introducción

# %% [markdown]
# Como objetivo general del proyecto, se busca desarrollar un modelo predictivo de riesgo crediticio, el cual permita al negocio reducir los resgos de préstamos y mejorar la calidad de los préstamos otorgados.
#
# Este modelo será utilizado para tomar decisiones más informadas, ofreciendo así, condiciones más favorables a aquellos con menor riesgo de impago.
#
#
# ### Metrica a utilizar
#
# Las métricas para evaluar el desempeño de modelos en el contexto de riesgo de crédito son:
#
# * **Recall**: Es la proporción de verdaderos positivos identificados correctamente entre todas las situaciones realmente positivas. Es crucial cuando las consecuencias de los falsos negativos son graves. En el riesgo de crédito, esto se traduce en identificar efectivamente a aquellos clientes con alta probabilidad de impago.
#
# * **Precision**: Esta métrica evalúa cuántos de los clientes identificados por el modelo como de alto riesgo realmente presentan ese alto riesgo. En el contexto de riesgo de crédito, una alta precision indica que una gran proporción de los clientes que el modelo clasifica como de alto riesgo son efectivamente clientes con alta probabilidad de impago.
#
# * **F1-score**: Es el promedio armónico de precisión y recall, proporcionando un equilibrio entre ambos. Es útil cuando ambos son críticos para el problema.
#
# Teniendo en cuenta el desbalance en los datos de la variable 'credit_score', con 5315 casos para la clase 0 (bajo riesgo de impago) y 2175 para la clase 1 (alto riesgo de impago), y considerando el objetivo de identificar eficientemente a los clientes de alto riesgo, la métrica más apropiada es el **Recall para la Clase 1**. Esto ayuda a minimizar el riesgo de otorgar préstamos a aquellos más propensos al impago.
#
# (Falta modelo y concluir)

# %% [markdown]
# - ID: An identifier for each record in the dataset.
# - Customer_ID: Identifier for individual customers.
# - Month: The month associated with the data entry.
# - Name: Customer's name.
# - Age: Customer's age.
# - SSN: Social Security Number or some other form of identification.
# - Occupation: Customer's occupation or job title.
# - Annual_Income: Customer's annual income.
# - Monthly_Inhand_Salary: The amount of money the customer receives as salary on a - monthly basis.
# - Num_Bank_Accounts: Number of bank accounts the customer has.
# - Num_Credit_Card: Number of credit cards the customer possesses.
# - Interest_Rate: The interest rate associated with some financial aspect (e.g., loans or credit cards).
# - Num_of_Loan: Number of loans the customer has.
# - Type_of_Loan: The type of loan(s) the customer has (e.g., mortgage, personal loan, etc.).
# - Delay_from_due_date: Delay in payments from the due date.
# - Num_of_Delayed_Payment: Number of delayed payments.
# - Changed_Credit_Limit: Indicates if the customer has changed their credit limit.
# - Num_Credit_Inquiries: Number of credit inquiries made by the customer.
# - Credit_Mix: The mix of different types of credit accounts (e.g., credit cards, loans).
# - Outstanding_Debt: The amount of outstanding debt.
# - Credit_Utilization_Ratio: The ratio of credit used to the total credit limit.
# - Credit_History_Age: The age of the customer's credit history.
# - Payment_of_Min_Amount: Payment behavior regarding minimum required payments.
# - Total_EMI_per_month: Total Equated Monthly Installment (EMI) payments made by the customer.
# - Amount_invested_monthly: The amount the customer invests on a monthly basis.
# - Payment_Behaviour: Behavior related to payments, possibly indicating patterns or trends.
# - Monthly_Balance: The customer's monthly balance in their financial accounts.
# - Credit_Score: The credit score associated with the customer's creditworthiness.

# %% [markdown]
# ## Preparación de los datos

# %%
# preprocesamiento

# %%
# vemos los tipos de datos
dataset.dtypes
# Out:
# customer_id                  object
# age                         float64
# occupation                   object
# annual_income               float64
# monthly_inhand_salary       float64
# num_bank_accounts             int64
# num_credit_card               int64
# interest_rate                 int64
# num_of_loan                 float64
# delay_from_due_date           int64
# num_of_delayed_payment      float64
# changed_credit_limit        float64
# num_credit_inquiries        float64
# outstanding_debt            float64
# credit_utilization_ratio    float64
# credit_history_age          float64
# payment_of_min_amount        object
# total_emi_per_month         float64
# amount_invested_monthly     float64
# payment_behaviour            object
# monthly_balance             float64
# credit_score                  int64
# dtype: object

# %%
# limpieza por tipo de dato

# age, no puede ser negativa ni mayor a 100
dataset = dataset[(dataset['age'] >= 0) & (dataset['age'] <= 100)]

# annual_income, no puede ser negativa
dataset = dataset[dataset['annual_income'] >= 0]

# monthly_inhand, no puede ser negativa
dataset = dataset[dataset['monthly_inhand_salary'] >= 0]

# num_bank_accounts, no puede ser negativa
dataset = dataset[dataset['num_bank_accounts'] >= 0]

# num_credit_card, no puede ser negativa
dataset = dataset[dataset['num_credit_card'] >= 0]

# interest_rate, no puede ser negativa
dataset = dataset[dataset['interest_rate'] >= 0]

# num_of_loan, no puede ser negativa
dataset = dataset[dataset['num_of_loan'] >= 0]

# delay_from_due_date, no puede ser negativa
dataset = dataset[dataset['delay_from_due_date'] >= 0]

# num_of_delayed_payment, no puede ser negativa
dataset = dataset[dataset['num_of_delayed_payment'] >= 0]

# changed_credit_limit, changed_credit_limit
dataset = dataset[dataset['changed_credit_limit'] >= 0]

# num_credit_inquiries, no puede ser negativa
dataset = dataset[dataset['num_credit_inquiries'] >= 0]

# outstanding_debt, no puede ser negativa
dataset = dataset[dataset['outstanding_debt'] >= 0]

# credit_utilization_ratio, no puede ser negativa
dataset = dataset[dataset['credit_utilization_ratio'] >= 0]

# credit_history_age, no puede ser negativa
dataset = dataset[dataset['credit_history_age'] >= 0]

# total_emi_per_month, no puede ser negativa
dataset = dataset[dataset['total_emi_per_month'] >= 0]

# amount_invested_monthly, no puede ser negativa
dataset = dataset[dataset['amount_invested_monthly'] >= 0]

# monthly_balance, puede ser negativa no se elimina

# credit_score, 0 o 1
dataset = dataset[(dataset['credit_score'] == 0) | (dataset['credit_score'] == 1)]

# %%
# detectamos las columnas catergoricas
categorical_columns = ['occupation', 'payment_of_min_amount', 'payment_behaviour']

# detectamos las columnas numericas 
numeric_columns_int = ['num_bank_accounts', 'num_credit_card', 'interest_rate',
                        'delay_from_due_date']

numeric_columns_float = ['age', 'annual_income', 'monthly_inhand_salary', 'num_of_loan',
                        'num_of_delayed_payment', 'changed_credit_limit',
                        'num_credit_inquiries', 'outstanding_debt', 'credit_utilization_ratio',
                        'credit_history_age', 'total_emi_per_month', 'amount_invested_monthly',
                        'monthly_balance']

# %%
# consideraciones para el preprocesamiento
# 1. eliminar columnas que no aportan informacion (customer_id)
# 2. detectar valores anormales (outliers), missings, valores nulos, valores negativos, etc

# eliminamos la columna customer_id
#dataset.drop('customer_id', axis=1, inplace=True)
#sample_dataset.drop('customer_id', axis=1, inplace=True)

# %%
sample_dataset  = dataset.sample(frac=0.1, random_state=42)

# %%
# creamos el column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('numeric_int', MinMaxScaler(), numeric_columns_int),
        ('numeric_float', MinMaxScaler(), numeric_columns_float),
        ('onehot', OneHotEncoder(sparse_output=False), categorical_columns)
    ]
)

preprocessor.set_output(transform='pandas')
# Out:
# ColumnTransformer(transformers=[('numeric_int', MinMaxScaler(),
#                                  ['num_bank_accounts', 'num_credit_card',
#                                   'interest_rate', 'delay_from_due_date']),
#                                 ('numeric_float', MinMaxScaler(),
#                                  ['age', 'annual_income',
#                                   'monthly_inhand_salary', 'num_of_loan',
#                                   'num_of_delayed_payment',
#                                   'changed_credit_limit',
#                                   'num_credit_inquiries', 'outstanding_debt',
#                                   'credit_utilization_ratio',
#                                   'credit_history_age', 'total_emi_per_month',
#                                   'amount_invested_monthly',
#                                   'monthly_balance']),
#                                 ('onehot', OneHotEncoder(sparse_output=False),
#                                  ['occupation', 'payment_of_min_amount',
#                                   'payment_behaviour'])])

# %%
# Holdout, dividir el dataset en train, val y test

# dividimos el dataset en train y val
X_train, X_test = train_test_split(sample_dataset, test_size=0.1, random_state=42)
X_train, X_val = train_test_split(X_train, test_size=0.2, random_state=42)

# separar la variable objetivo, credit_score
y_train = X_train['credit_score']
X_train.drop('credit_score', axis=1, inplace=True)

y_val = X_val['credit_score']
X_val.drop('credit_score', axis=1, inplace=True)

y_test = X_test['credit_score']
X_test.drop('credit_score', axis=1, inplace=True)

# %%
dataset['credit_score'].value_counts()
# Out:
# 0    5315
# 1    2175
# Name: credit_score, dtype: int64

# %% [markdown]
# ## Baseline

# %%
clase_obj = 'class_1'
metrica_obj = 'recall'

# creamos los pipelines para los modelos

# pipeline dummy (baseline)
dummy_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('dummy', DummyClassifier(strategy='most_frequent', random_state=42))
    ]
)


# initial time
start_time = tm.time()

# train
dummy_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time
time = end_time - start_time

# predict
y_pred = dummy_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)

metrics = {"dummy": {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time	
}}
# Out:
# e:\Python\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\Python\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\Python\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# pipeline logistic regression

logisticRef_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('logistic', LogisticRegression(random_state=42))
    ]
)

# initial time
start_time = tm.time()

# train
logisticRef_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time
time = end_time - start_time

# predict
y_pred = logisticRef_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)


metrics["logistic"] = {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time
}

# %%
# pipeline KNeighborsClassifier

knn_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('knn', KNeighborsClassifier(n_neighbors=5))
    ]
)
    
# initial time
start_time = tm.time()

# train
knn_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time

# predict
y_pred = knn_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)

metrics["knn"] = {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time
}

# %%
# pipeline DecisionTreeClassifier

decisionTree_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('decisionTree', DecisionTreeClassifier(random_state=42))
    ]
)
# initial time
start_time = tm.time()

# train
decisionTree_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time
time = end_time - start_time

# predict
y_pred = decisionTree_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)

metrics["decisionTree"] = {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time
}

# %%
# pipeline SVC

svc_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('svc', SVC(random_state=42))
    ]
)
# initial time
start_time = tm.time()

# train
svc_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time  
time = end_time - start_time

# predict
y_pred = svc_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)

metrics["svc"] = {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time
}

# %%
# pipeline RandomForestClassifier

randomForest_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('randomForest', RandomForestClassifier(random_state=42))
    ]
)
# initial time
start_time = tm.time()

# train
randomForest_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time
time = end_time - start_time

# predict
y_pred = randomForest_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)

metrics["rf"] = {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time
}

# %%
# pipeline LGBMClassifier

lgbm_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('lgbm', LGBMClassifier(random_state=42))
    ]
)
# initial time  
start_time = tm.time()

# train
lgbm_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time  
time = end_time - start_time

# predict
y_pred = lgbm_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)

metrics["lgmb"] = {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time
}
# Out:
# [LightGBM] [Info] Number of positive: 153, number of negative: 386
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000199 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1725
# [LightGBM] [Info] Number of data points in the train set: 539, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.283859 -> initscore=-0.925399
# [LightGBM] [Info] Start training from score -0.925399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# pipeline XGBClassifier

xgb_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('implace', SimpleImputer(strategy='most_frequent')),
        ('xgb', XGBClassifier(random_state=42))
    ]
)

# initial time

# train
xgb_pipeline.fit(X_train, y_train)

# end time
end_time = tm.time()

# time  
time = end_time - start_time

# predict
y_pred = xgb_pipeline.predict(X_val)

# report
report = classification_report(y_val, y_pred, output_dict=True)

metrics["xgb"] = {
    "class_0":report['0'][metrica_obj],
    "class_1":report['1'][metrica_obj],
    "weighted_avg":report['macro avg'][metrica_obj],
    "time":time
}

# %%
metrics
# Out:
# {'dummy': {'class_0': 1.0,
#   'class_1': 0.0,
#   'weighted_avg': 0.5,
#   'time': 0.045996904373168945},
#  'logistic': {'class_0': 0.839622641509434,
#   'class_1': 0.3793103448275862,
#   'weighted_avg': 0.6094664931685101,
#   'time': 0.06400275230407715},
#  'knn': {'class_0': 0.8490566037735849,
#   'class_1': 0.27586206896551724,
#   'weighted_avg': 0.5624593363695511,
#   'time': 0.06400275230407715},
#  'decisionTree': {'class_0': 0.7452830188679245,
#   'class_1': 0.4482758620689655,
#   'weighted_avg': 0.596779440468445,
#   'time': 0.051003217697143555},
#  'svc': {'class_0': 0.8584905660377359,
#   'class_1': 0.3103448275862069,
#   'weighted_avg': 0.5844176968119714,
#   'time': 0.04899954795837402},
#  'rf': {'class_0': 0.8962264150943396,
#   'class_1': 0.4482758620689655,
#   'weighted_avg': 0.6722511385816525,
#   'time': 0.36199474334716797},
#  'lgmb': {'class_0': 0.8962264150943396,
#   'class_1': 0.4827586206896552,
#   'weighted_avg': 0.6894925178919974,
#   'time': 0.10551667213439941},
#  'xgb': {'class_0': 0.8679245283018868,
#   'class_1': 0.4827586206896552,
#   'weighted_avg': 0.675341574495771,
#   'time': 0.2651660442352295}}

# %%
# metrics to dataframe
# Crear un DataFrame desde el diccionario
df_metrics = pd.DataFrame.from_dict(metrics, orient='index')

df_metrics.sort_values(by=clase_obj, ascending=False, inplace=True)
df_metrics
# Out:
#                class_0   class_1  weighted_avg      time
# lgmb          0.896226  0.482759      0.689493  0.105517
# xgb           0.867925  0.482759      0.675342  0.265166
# decisionTree  0.745283  0.448276      0.596779  0.051003
# rf            0.896226  0.448276      0.672251  0.361995
# logistic      0.839623  0.379310      0.609466  0.064003
# svc           0.858491  0.310345      0.584418  0.049000
# knn           0.849057  0.275862      0.562459  0.064003
# dummy         1.000000  0.000000      0.500000  0.045997

# %% [markdown]
# Considerando que la métrica a evaluar es Recall para la clase 1, se puede observar en el dataframe que todos los modelos superan a dummy. El valor máximo es 0.4827 alcanzado tanto por LightGBMClassifier y XGBClassifier, esto se puede explicar debido a que estan basados en Gradient Boosting para la optimización de su función de pérdida de manera efectiva, además, estos modelos combinan múltiples árboles de decisión débiles de manera iterativa para formar un modelo robusto, ajustando constantemente los errores de las iteraciones anteriores y mejorando la precisión con cada paso.
#
# En cuanto al tiempo de entrenamiento, los modelos con mejores resultados LightGBMClassifier y XGBClassifier, son de los que más tardan, teniendo las posiciones 3era y 2da respectivamente, por lo que podrian no ser los mejores a la hora de probar muchas combinaciones.

# %% [markdown]
# ## Optimización del Modelo

# %% [markdown]
# ## 1er mejor modelo: LightGBMClassifier

# %%
def objective_function_lgb(trial):
    # Define the hyperparameters to tune
    params = {
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
        "n_estimators": trial.suggest_int("n_estimators", 50, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "num_leaves": trial.suggest_int("num_leaves", 31, 150),  
        "min_child_samples": trial.suggest_int("min_child_samples", 20, 100),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 1.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 1.0),
    }

    X_train_preprocessed = preprocessor.fit_transform(X_train)
    X_val_preprocessed = preprocessor.transform(X_val)

    # Imputation of missing values
    imputer = SimpleImputer(strategy='most_frequent')
    X_train_imputed = imputer.fit_transform(X_train_preprocessed)
    X_val_imputed = imputer.transform(X_val_preprocessed)

    # Create and train the model
    model = LGBMClassifier(random_state=42, **params,
                           early_stopping_rounds=15,
                           verbosity=-1)
    model.fit(
        X_train_imputed, y_train,
        eval_set=[(X_val_imputed, y_val)],
        callbacks=[optuna.integration.LightGBMPruningCallback(trial, "binary_logloss")]
    )

    # Predict and evaluate the model
    y_pred = model.predict(X_val_imputed)
    recall = classification_report(y_val, y_pred, output_dict=True)['1'][metrica_obj]

    return recall

# %%
study = optuna.create_study(direction="minimize", sampler=TPESampler(seed=42))
study.optimize(objective_function_lgb, timeout=300, n_jobs=10)
# Out:
# [I 2023-12-18 02:14:48,116] A new study created in memory with name: no-name-d582b1aa-c590-44ba-8de5-023b6573a7d2
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:48,971] Trial 5 finished with value: 0.4482758620689655 and parameters: {'learning_rate': 0.05103272354488386, 'n_estimators': 386, 'max_depth': 7, 'num_leaves': 48, 'min_child_samples': 64, 'reg_alpha': 0.6514896550571502, 'reg_lambda': 0.16747963739750427}. Best is trial 5 with value: 0.4482758620689655.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:49,057] Trial 0 finished with value: 0.41379310344827586 and parameters: {'learning_rate': 0.09402214842439284, 'n_estimators': 670, 'max_depth': 6, 'num_leaves': 123, 'min_child_samples': 95, 'reg_alpha': 0.11912261847247341, 'reg_lambda': 0.645240453299818}. Best is trial 0 with value: 0.41379310344827586.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:49,088] Trial 8 finished with value: 0.4482758620689655 and parameters: {'learning_rate': 0.05044047917695858, 'n_estimators': 216, 'max_depth': 9, 'num_leaves': 32, 'min_child_samples': 70, 'reg_alpha': 0.04574483255986583, 'reg_lambda': 0.5504902500736025}. Best is trial 0 with value: 0.41379310344827586.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:49,154] Trial 6 finished with value: 0.4482758620689655 and parameters: {'learning_rate': 0.05361639373118647, 'n_estimators': 70, 'max_depth': 4, 'num_leaves': 123, 'min_child_samples': 21, 'reg_alpha': 0.33786391101974045, 'reg_lambda': 0.3966418216960085}. Best is trial 0 with value: 0.41379310344827586.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:49,331] Trial 1 finished with value: 0.4482758620689655 and parameters: {'learning_rate': 0

# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:59,276] Trial 88 finished with value: 0.4827586206896552 and parameters: {'learning_rate': 0.0715354656870907, 'n_estimators': 473, 'max_depth': 5, 'num_leaves': 65, 'min_child_samples': 39, 'reg_alpha': 0.4853483064380518, 'reg_lambda': 0.298139483221474}. Best is trial 7 with value: 0.20689655172413793.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:59,449] Trial 90 pruned. Trial was pruned at iteration 7.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:59,499] Trial 91 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:59,601] Trial 89 finished with value: 0.4827586206896552 and parameters: {'learning_rate': 0.07070590006266236, 'n_estimators': 202, 'max_depth': 3, 'num_leaves': 128, 'min_child_samples': 36, 'reg_alpha': 0.0002802265029240303, 'reg_lambda': 0.28297814808887395}. Best is trial 7 with value: 0.20689655172413793.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:59,624] Trial 92 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:14:59,824] Trial 93 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:14:59,937] Trial 94 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:15:00,183] Trial 95 pruned. Trial was pruned at iteration 7.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:15:00,286] Trial 96 pruned. Trial was pruned at iteration 11.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:15:00,469] Trial 101 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:15:00,478] Trial 99 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:15:00,480] Trial 97 pruned. Trial was pruned at iteration 9.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:15:00,644] Trial 102 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:15:00,715] Trial 98 pruned. Trial was pruned at iteration 9.
# [I 2023-12-18 02:15:01,082] Trial 100 pruned. Trial was pruned at iteration 0.
# ...
# [I 2023-12-18 02:19:37,937] Trial 1508 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:38,064] Trial 1509 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:38,081] Trial 1506 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:38,345] Trial 1510 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:38,742] Trial 1511 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:38,743] Trial 1512 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:38,980] Trial 1513 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:39,539] Trial 1514 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:39,772] Trial 1515 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:40,524] Trial 1517 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:40,559] Trial 1516 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:40,674] Trial 1519 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:40,788] Trial 1518 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:40,998] Trial 1520 pruned. Trial was pruned at iteration 2.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:41,098] Trial 1523 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:41,120] Trial 1521 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:41,744] Trial 1522 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:41,929] Trial 1524 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:42,310] Trial 1525 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:43,180] Trial 1527 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:43,268] Trial 1530 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:43,339] Trial 1526 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:43,436] Trial 1528 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:43,486] Trial 1532 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:43,497] Trial 1529 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:43,746] Trial 1531 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:44,204] Trial 1534 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:44,595] Trial 1533 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:44,925] Trial 1535 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:45,780] Trial 1536 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:45,907] Trial 1539 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:46,017] Trial 1537 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:46,136] Trial 1538 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:46,168] Trial 1540 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:46,273] Trial 1541 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:46,317] Trial 1542 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:46,997] Trial 1543 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:47,227] Trial 1544 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:47,772] Trial 1545 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\2841231006.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:19:48,605] Trial 1550 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,619] Trial 1547 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,680] Trial 1546 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,775] Trial 1552 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,780] Trial 1551 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,856] Trial 1549 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,876] Trial 1548 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,977] Trial 1553 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,990] Trial 1555 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:19:48,999] Trial 1554 pruned. Trial was pruned at iteration 0.

# %%
# print del mejor resultado
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# Best trial: score 0.20689655172413793,
# params {'learning_rate': 0.004624943945967205, 'n_estimators': 139, 'max_depth': 3, 'num_leaves': 46, 'min_child_samples': 24, 'reg_alpha': 0.44818559578492756, 'reg_lambda': 0.32382902171531114}

# %% [markdown]
# ### 2do mejor modelo: XGBClassifier

# %%
def objective_function_xgb(trial):
    # Define the hyperparameters to tune
    params = {
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
        "n_estimators": trial.suggest_int("n_estimators", 50, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 5),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 1.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 1.0),
    }

    X_train_preprocessed = preprocessor.fit_transform(X_train)
    X_val_preprocessed = preprocessor.transform(X_val)

    # Imputation of missing values
    imputer = SimpleImputer(strategy='most_frequent')
    X_train_imputed = imputer.fit_transform(X_train_preprocessed)
    X_val_imputed = imputer.transform(X_val_preprocessed)

    # Create and train the model
    model = XGBClassifier(random_state=42, **params,
                          early_stopping_rounds=15,)
    model.fit(
        X_train_imputed, y_train,
        eval_set=[(X_val_imputed, y_val)],
        verbose=False,
        callbacks=[optuna.integration.XGBoostPruningCallback(trial, "validation_0-logloss")]
    )

    # Predict and evaluate the model
    y_pred = model.predict(X_val_imputed)
    recall = classification_report(y_val, y_pred, output_dict=True)['1'][metrica_obj]

    return recall

# %%
study = optuna.create_study(direction="maximize", sampler=TPESampler(seed=42))
study.optimize(objective_function_xgb, timeout=300, n_jobs=10)
# Out:
# [I 2023-12-18 02:21:54,366] A new study created in memory with name: no-name-f69e670f-2f16-414a-bc47-6fb6e249253a
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:21:55,591] Trial 9 finished with value: 0.41379310344827586 and parameters: {'learning_rate': 0.0604436358328313, 'n_estimators': 140, 'max_depth': 7, 'min_child_weight': 1, 'reg_alpha': 0.3116423131612661, 'reg_lambda': 0.45521107742765976}. Best is trial 9 with value: 0.41379310344827586.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:21:55,676] Trial 2 finished with value: 0.41379310344827586 and parameters: {'learning_rate': 0.04247905846246006, 'n_estimators': 127, 'max_depth': 8, 'min_child_weight': 4, 'reg_alpha': 0.7825609144300386, 'reg_lambda': 0.03601591107275459}. Best is trial 9 with value: 0.41379310344827586.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:21:55,737] Trial 7 finished with value: 0.5517241379310345 and parameters: {'learning_rate': 0.05255987604126281, 'n_estimators': 593, 'max_depth': 3, 'min_child_weight': 2, 'reg_alpha': 0.9198773950514499, 'reg_lambda': 0.8031781495270937}. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:21:56,122] Trial 10 finished with value: 0.4482758620689655 and parameters: {'learning_rate': 0.07023289172527764, 'n_estimators': 986, 'max_depth': 7, 'min_child_weight': 5, 'reg_alpha': 0.0018157450309888024, 'reg_lambda': 0.6680952004150714}. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:21:56,289] Trial 1 finished with value: 0.3448275862068966 and parameters: {'learning_rate': 0.012759214626999013, 'n_estimators': 202, 'max_depth': 10, 'min_child_weight': 1, 'reg_alpha': 0.44322711996197217, 'reg_lambda': 0.5504661923075143}. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:21:56,421] Trial 14 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:21:56,529] Trial 11 finished with value: 0.3448275862068966 and parameters: {'learning_rate': 0.024318848436176557, 'n_estimators': 162, 'max_depth': 8, 'min_child_weight': 1, 'reg_alpha': 0.22133926177233054, 'reg_lambda': 0.2947947025918989}. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:21:56,612] Trial 15 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:21:56,963] Trial 0 finished with value: 0.5172413793103449 and parameters: {'learning_rate': 0.003866648478926477, 'n_estimators': 539, 'max_depth': 3, 'min_child_weight': 5, 'reg_alpha': 0.3409425290466087, 'reg_lambda': 0.7384933078539546}. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02
. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:26:51,168] Trial 1300 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:51,664] Trial 1301 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:51,818] Trial 1304 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:52,289] Trial 1248 finished with value: 0.3448275862068966 and parameters: {'learning_rate': 0.0010004604473899169, 'n_estimators': 600, 'max_depth': 3, 'min_child_weight': 1, 'reg_alpha': 0.7653095609654895, 'reg_lambda': 0.9426120907488068}. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:52,503] Trial 1306 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:26:52,604] Trial 1305 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:52,923] Trial 1307 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:26:52,986] Trial 1243 finished with value: 0.5172413793103449 and parameters: {'learning_rate': 0.0017158577711257146, 'n_estimators': 697, 'max_depth': 3, 'min_child_weight': 1, 'reg_alpha': 0.8564118601353655, 'reg_lambda': 0.9385418851826098}. Best is trial 7 with value: 0.5517241379310345.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:53,215] Trial 1308 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:53,413] Trial 1309 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:54,086] Trial 1310 pruned. Trial was pruned at iteration 0.
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# [I 2023-12-18 02:26:54,167] Trial 1311 pruned. Trial was pruned at iteration 0.
# C:\Users\hakup\AppData\Local\Temp\ipykernel_9492\1631945529.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.1),
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:54,471] Trial 1312 pruned. Trial was pruned at iteration 0.
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:54,583] Trial 1315 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:26:54,591] Trial 1313 pruned. Trial was pruned at iteration 0.
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:54,702] Trial 1314 pruned. Trial was pruned at iteration 0.
# e:\Python\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-18 02:26:55,042] Trial 1317 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:26:55,046] Trial 1316 pruned. Trial was pruned at iteration 0.
# [I 2023-12-18 02:26:57,068] Trial 1293 finished with value: 0.4827586206896552 and parameters: {'learning_rate': 0.0015497332756848386, 'n_estimators': 674, 'max_depth': 3, 'min_child_weight': 5, 'reg_alpha': 0.9994855301167594, 'reg_lambda': 0.8659773963723624}. Best is trial 7 with value: 0.5517241379310345.
# [I 2023-12-18 02:26:57,153] Trial 1298 finished with value: 0.5172413793103449 and parameters: {'learning_rate': 0.0015319656384826352, 'n_estimators': 679, 'max_depth': 3, 'min_child_weight': 2, 'reg_alpha': 0.849298289757081, 'reg_lambda': 0.860478518286681}. Best is trial 7 with value: 0.5517241379310345.
# [I 2023-12-18 02:26:57,381] Trial 1302 finished with value: 0.5172413793103449 and parameters: {'learning_rate': 0.0015421928700877123, 'n_estimators': 653, 'max_depth': 3, 'min_child_weight': 2, 'reg_alpha': 0.8811632438228686, 'reg_lambda': 0.9183047271938177}. Best is trial 7 with value: 0.5517241379310345.
# [I 2023-12-18 02:26:57,394] Trial 1303 finished with value: 0.5172413793103449 and parameters: {'learning_rate': 0.001555662212354593, 'n_estimators': 651, 'max_depth': 3, 'min_child_weight': 2, 'reg_alpha': 0.7605551136318697, 'reg_lambda': 0.6910682094948142}. Best is trial 7 with value: 0.5517241379310345.

# %%
# print del mejor resultado
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))
# Out:
# Best trial: score 0.5517241379310345,
# params {'learning_rate': 0.05255987604126281, 'n_estimators': 593, 'max_depth': 3, 'min_child_weight': 2, 'reg_alpha': 0.9198773950514499, 'reg_lambda': 0.8031781495270937}
